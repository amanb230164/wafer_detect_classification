# %%
import os

print(os.listdir(r"G:\My Drive"))
# Out:
# ['WA-IMG-20200919-de093c0a.jpg', 'WA-IMG-20200919-7e6fc97b.jpg', 'Photo from Aman Raj', 'CLASS-XII.rar', 'CLASS-XI.rar', 'Aman Raj tutorial sheet .pdf', 'Emailing mos differential pair tutorial 3 soln Aman Raj.pdf', 'Document from Aman Raj.pdf', 'aman class X marksheet.pdf', 'class X marksheet amaan.pdf', 'Aman Raj grade card 1-4.pdf', 'archive.zip', 'archive (1).zip', 'Colab Notebooks', 'wm-811k.zip', 'wafer_data', 'wafer_best_model.pth', 'wafer_checkpoint.pth', 'desktop.ini']

# %%
import os

print(os.listdir(r"G:\My Drive\wafer_data"))
# Out:
# ['LSWMD_meta.csv', 'wafer_maps.npy', 'sample_wafer_maps.png']

# %%
import pandas as pd

meta = pd.read_csv(r"G:\My Drive\wafer_data\LSWMD_meta.csv")

print(meta.shape)
print(meta.columns)
print(meta.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2
#       3 meta = pd.read_csv(r"G:\My Drive\wafer_data\LSWMD_meta.csv")
#       4
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\amanv\AppData\Local\Programs\Python\Python313\python.exe

# %%
import sys

# !{sys.executable} -m pip install pandas numpy matplotlib scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 5.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.8 MB 7.6 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.8 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.8 MB 9.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 9.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------- ----------------------------- 3.1/12.3 MB 14.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.3 MB 18.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 15.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import numpy as np

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Pandas: 3.0.3
# NumPy: 2.4.6

# %%
import sys

# !{sys.executable} -m pip install torch torchvision torchaudio
# Out:
# ...
#    ---------------------------------------- 0.0/123.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/123.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/123.0 MB 1.3 MB/s eta 0:01:34
#    ---------------------------------------- 1.0/123.0 MB 1.9 MB/s eta 0:01:03
#     --------------------------------------- 1.6/123.0 MB 2.1 MB/s eta 0:00:57
#     --------------------------------------- 2.1/123.0 MB 2.2 MB/s eta 0:00:54
#     --------------------------------------- 2.9/123.0 MB 2.6 MB/s eta 0:00:47
#    - -------------------------------------- 3.4/123.0 MB 2.6 MB/s eta 0:00:47
#    - -------------------------------------- 4.2/123.0 MB 2.7 MB/s eta 0:00:44
#    - -------------------------------------- 5.0/123.0 MB 2.9 MB/s eta 0:00:41
#    - -------------------------------------- 6.0/123.0 MB 3.1 MB/s eta 0:00:38
#    -- ------------------------------------- 6.8/123.0 MB 3.2 MB/s eta 0:00:37
# ...

# %%
import torch

print(torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
# Out:
# 2.12.1+cpu
# CUDA Available: False

# %%
import pandas as pd

meta = pd.read_csv(
    r"G:\My Drive\wafer_data\LSWMD_meta.csv"
)

print(meta.shape)
print(meta.columns.tolist())
# Out:
# (811457, 6)
# ['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel', 'failureType']

# %%
print(meta['failureType'].value_counts())
# Out:
# failureType
# []                 638507
# [['none']]         147431
# [['Edge-Ring']]      9680
# [['Edge-Loc']]       5189
# [['Center']]         4294
# [['Loc']]            3593
# [['Scratch']]        1193
# [['Random']]          866
# [['Donut']]           555
# [['Near-full']]       149
# Name: count, dtype: int64

# %%
import numpy as np

wafer_maps = np.load(
    r"G:\My Drive\wafer_data\wafer_maps.npy",
    allow_pickle=True
)

print("Wafer maps:", len(wafer_maps))
print("Shape of first wafer:", wafer_maps[0].shape)
# Out:
# Wafer maps: 811457
# Shape of first wafer: (45, 48)

# %%
import torch

print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA: False

# %%
torch.cuda.is_available()
# Out:
# False

# %%
print(meta.columns)

print(meta.head())

print(meta['failureType'].head())
# Out:
# Index(['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel',
#        'failureType'],
#       dtype='str')
#    Unnamed: 0  dieSize lotName  waferIndex  trianTestLabel failureType
# 0           0   1683.0    lot1         1.0  [['Training']]  [['none']]
# 1           1   1683.0    lot1         2.0  [['Training']]  [['none']]
# 2           2   1683.0    lot1         3.0  [['Training']]  [['none']]
# 3           3   1683.0    lot1         4.0  [['Training']]  [['none']]
# 4           4   1683.0    lot1         5.0  [['Training']]  [['none']]
# 0    [['none']]
# 1    [['none']]
# 2    [['none']]
# 3    [['none']]
# 4    [['none']]
# Name: failureType, dtype: str

# %%
df_small = (
    meta.groupby('failureType', group_keys=False)
        .apply(lambda x: x.sample(
            min(len(x), 2000),
            random_state=42
        ))
)

print(type(df_small))
print(df_small.columns)
print(df_small.head())
# Out:
# <class 'pandas.DataFrame'>
# Index(['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel'], dtype='str')
#         Unnamed: 0  dieSize   lotName  waferIndex  trianTestLabel
# 679719      679719    843.0  lot42198        15.0      [['Test']]
# 592107      592107    515.0  lot36981        16.0  [['Training']]
# 764495      764495    904.0  lot45630        24.0      [['Test']]
# 762062      762062   1109.0  lot45532        10.0      [['Test']]
# 721701      721701    518.0  lot43898        11.0      [['Test']]

# %%
print(meta['failureType'].dtype)

print(meta['failureType'].iloc[0])

print(type(meta['failureType'].iloc[0]))
# Out:
# str
# [['none']]
# <class 'str'>

# %%
meta['failureType'] = (
    meta['failureType']
    .str.replace(r"\[\['", "", regex=True)
    .str.replace(r"'\]\]", "", regex=True)
)

print(meta['failureType'].head())
# Out:
# 0    none
# 1    none
# 2    none
# 3    none
# 4    none
# Name: failureType, dtype: str

# %%
print(meta['failureType'].value_counts())
# Out:
# failureType
# []           638507
# none         147431
# Edge-Ring      9680
# Edge-Loc       5189
# Center         4294
# Loc            3593
# Scratch        1193
# Random          866
# Donut           555
# Near-full       149
# Name: count, dtype: int64

# %%
meta = meta[meta['failureType'] != '[]'].copy()

print(meta['failureType'].value_counts())
# Out:
# failureType
# none         147431
# Edge-Ring      9680
# Edge-Loc       5189
# Center         4294
# Loc            3593
# Scratch        1193
# Random          866
# Donut           555
# Near-full       149
# Name: count, dtype: int64

# %%
MAX_PER_CLASS = 149

# %%
print(df_small.columns)
print(df_small.head())
# Out:
# Index(['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel'], dtype='str')
#    Unnamed: 0  dieSize   lotName  waferIndex  trianTestLabel
# 0      679719    843.0  lot42198        15.0      [['Test']]
# 1      592107    515.0  lot36981        16.0  [['Training']]
# 2      764495    904.0  lot45630        24.0      [['Test']]
# 3      762062   1109.0  lot45532        10.0      [['Test']]
# 4      721701    518.0  lot43898        11.0      [['Test']]

# %%
print(meta.columns)
# Out:
# Index(['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel',
#        'failureType'],
#       dtype='str')

# %%
print(meta.columns.tolist())

# Verify column exists
print("failureType" in meta.columns)

# Create balanced dataset
groups = []

for cls in meta['failureType'].unique():

    temp = meta[meta['failureType'] == cls]

    n = min(len(temp), 149)

    groups.append(
        temp.sample(n=n, random_state=42)
    )

df_small = pd.concat(groups).reset_index(drop=True)

print(df_small.columns.tolist())
print(df_small['failureType'].value_counts())
print("Total samples:", len(df_small))
# Out:
# ['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel', 'failureType']
# True
# ['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel', 'failureType']
# failureType
# none         149
# Loc          149
# Edge-Loc     149
# Center       149
# Edge-Ring    149
# Scratch      149
# Random       149
# Near-full    149
# Donut        149
# Name: count, dtype: int64
# Total samples: 1341

# %%
print(meta.columns.tolist())
print(meta.head())
# Out:
# ['Unnamed: 0', 'dieSize', 'lotName', 'waferIndex', 'trianTestLabel', 'failureType']
#    Unnamed: 0  dieSize lotName  waferIndex  trianTestLabel failureType
# 0           0   1683.0    lot1         1.0  [['Training']]        none
# 1           1   1683.0    lot1         2.0  [['Training']]        none
# 2           2   1683.0    lot1         3.0  [['Training']]        none
# 3           3   1683.0    lot1         4.0  [['Training']]        none
# 4           4   1683.0    lot1         5.0  [['Training']]        none

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df_small['label'] = le.fit_transform(
    df_small['failureType']
)

print(le.classes_)
print("Number of classes:", len(le.classes_))
# Out:
# ['Center' 'Donut' 'Edge-Loc' 'Edge-Ring' 'Loc' 'Near-full' 'Random'
#  'Scratch' 'none']
# Number of classes: 9

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(
    df_small,
    test_size=0.2,
    stratify=df_small['label'],
    random_state=42
)

print("Train:", len(train_df))
print("Val:", len(val_df))
# Out:
# Train: 1072
# Val: 269

# %%
print(df_small['failureType'].value_counts())
print("Train:", len(train_df))
print("Val:", len(val_df))
# Out:
# failureType
# none         149
# Loc          149
# Edge-Loc     149
# Center       149
# Edge-Ring    149
# Scratch      149
# Random       149
# Near-full    149
# Donut        149
# Name: count, dtype: int64
# Train: 1072
# Val: 269

# %%
import numpy as np

wafer_maps = np.load(
    r"G:\My Drive\wafer_data\wafer_maps.npy",
    allow_pickle=True
)

print("Total wafer maps:", len(wafer_maps))
print("First wafer shape:", wafer_maps[0].shape)
# Out:
# Total wafer maps: 811457
# First wafer shape: (45, 48)

# %%
train_indices = train_df['Unnamed: 0'].values
val_indices = val_df['Unnamed: 0'].values

train_maps = wafer_maps[train_indices]
val_maps = wafer_maps[val_indices]

print("Train maps:", len(train_maps))
print("Val maps:", len(val_maps))
# Out:
# Train maps: 1072
# Val maps: 269

# %%
import torch
from torch.utils.data import Dataset
import numpy as np
from PIL import Image

class WaferDataset(Dataset):

    def __init__(self, wafer_maps, labels):

        self.wafer_maps = wafer_maps
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):

        wafer = np.array(
            self.wafer_maps[idx],
            dtype=np.uint8
        )

        # normalize values
        wafer = wafer * 127

        wafer = np.stack(
            [wafer, wafer, wafer],
            axis=-1
        )

        wafer = Image.fromarray(
            wafer.astype(np.uint8)
        )

        wafer = wafer.resize((64, 64))

        wafer = np.array(wafer)

        wafer = (
            torch.tensor(
                wafer,
                dtype=torch.float32
            )
            .permute(2, 0, 1)
            / 255.0
        )

        label = torch.tensor(
            self.labels[idx],
            dtype=torch.long
        )

        return wafer, label

# %%
train_labels = train_df['label'].values
val_labels = val_df['label'].values

train_dataset = WaferDataset(
    train_maps,
    train_labels
)

val_dataset = WaferDataset(
    val_maps,
    val_labels
)

print(len(train_dataset))
print(len(val_dataset))
# Out:
# 1072
# 269

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
# Out:
# Train batches: 34
# Val batches: 9

# %%
imgs, labels = next(iter(train_loader))

print(imgs.shape)
print(labels.shape)
# Out:
# torch.Size([32, 3, 64, 64])
# torch.Size([32])

# %%
print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))

imgs, labels = next(iter(train_loader))
print(imgs.shape)
print(labels.shape)
# Out:
# Train batches: 34
# Val batches: 9
# torch.Size([32, 3, 64, 64])
# torch.Size([32])

# %%
import torch
import torch.nn as nn

num_classes = len(le.classes_)

class WaferCNN(nn.Module):

    def __init__(self, num_classes):

        super().__init__()

        self.features = nn.Sequential(

            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(

            nn.Flatten(),

            nn.Linear(
                128 * 8 * 8,
                256
            ),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(
                256,
                num_classes
            )
        )

    def forward(self, x):

        x = self.features(x)

        x = self.classifier(x)

        return x

model = WaferCNN(num_classes)

print(model)
# Out:
# WaferCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=8192, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=256, out_features=9, bias=True)
#   )
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=0.001
)

# %%
from sklearn.metrics import f1_score
import torch

EPOCHS = 20

best_f1 = 0.0
patience = 5
counter = 0

for epoch in range(EPOCHS):

    # ------------------
    # TRAIN
    # ------------------
    model.train()

    running_loss = 0.0

    for imgs, labels in train_loader:

        optimizer.zero_grad()

        outputs = model(imgs)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

    train_loss = running_loss / len(train_loader)

    # ------------------
    # VALIDATION
    # ------------------
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():

        for imgs, labels in val_loader:

            outputs = model(imgs)

            preds = outputs.argmax(dim=1)

            all_preds.extend(preds.numpy())
            all_labels.extend(labels.numpy())

    val_f1 = f1_score(
        all_labels,
        all_preds,
        average='macro',
        zero_division=0
    )

    print(
        f"Epoch [{epoch+1}/{EPOCHS}] | "
        f"Loss: {train_loss:.4f} | "
        f"Val F1: {val_f1:.4f}"
    )

    # ------------------
    # SAVE BEST MODEL
    # ------------------
    if val_f1 > best_f1:

        best_f1 = val_f1
        counter = 0

        torch.save(
            model.state_dict(),
            "wafer_best_model.pth"
        )

        print(
            f"✓ Best model saved (F1={best_f1:.4f})"
        )

    else:

        counter += 1

        print(
            f"No improvement ({counter}/{patience})"
        )

        if counter >= patience:

            print(
                f"\nEarly stopping at epoch {epoch+1}"
            )

            break

print("\nTraining Complete")
print(f"Best Validation F1: {best_f1:.4f}")
# Out:
# Epoch [1/20] | Loss: 0.7914 | Val F1: 0.7126
# ✓ Best model saved (F1=0.7126)
# Epoch [2/20] | Loss: 0.7143 | Val F1: 0.6627
# No improvement (1/5)
# Epoch [3/20] | Loss: 0.6366 | Val F1: 0.7180
# ✓ Best model saved (F1=0.7180)
# Epoch [4/20] | Loss: 0.5911 | Val F1: 0.7376
# ✓ Best model saved (F1=0.7376)
# Epoch [5/20] | Loss: 0.5224 | Val F1: 0.7203
# No improvement (1/5)
# Epoch [6/20] | Loss: 0.4735 | Val F1: 0.7914
# ✓ Best model saved (F1=0.7914)
# Epoch [7/20] | Loss: 0.4122 | Val F1: 0.7314
# No improvement (1/5)
# Epoch [8/20] | Loss: 0.4807 | Val F1: 0.7408
# No improvement (2/5)
# Epoch [9/20] | Loss: 0.3487 | Val F1: 0.7333
# No improvement (3/5)
# Epoch [10/20] | Loss: 0.2885 | Val F1: 0.7403
# No improvement (4/5)
# Epoch [11/20] | Loss: 0.3116 | Val F1: 0.7824
# No improvement (5/5)
#
# Early stopping at epoch 11
#
# Training Complete
# Best Validation F1: 0.7914

# %%
model.load_state_dict(
    torch.load(
        "wafer_best_model.pth",
        map_location="cpu"
    )
)

model.eval()

print("Best model loaded.")
# Out:
# Best model loaded.

# %%
from sklearn.metrics import classification_report

all_preds = []
all_labels = []

with torch.no_grad():

    for imgs, labels in val_loader:

        outputs = model(imgs)

        preds = outputs.argmax(dim=1)

        all_preds.extend(preds.numpy())
        all_labels.extend(labels.numpy())

print(
    classification_report(
        all_labels,
        all_preds,
        target_names=le.classes_
    )
)
# Out:
#               precision    recall  f1-score   support
#
#       Center       0.94      0.97      0.95        30
#        Donut       0.87      0.90      0.89        30
#     Edge-Loc       0.66      0.70      0.68        30
#    Edge-Ring       1.00      0.83      0.91        30
#          Loc       0.87      0.43      0.58        30
#    Near-full       1.00      1.00      1.00        30
#       Random       0.94      1.00      0.97        30
#      Scratch       0.62      0.45      0.52        29
#         none       0.50      0.87      0.63        30
#
#     accuracy                           0.80       269
#    macro avg       0.82      0.79      0.79       269
# weighted avg       0.82      0.80      0.79       269

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

cm = confusion_matrix(
    all_labels,
    all_preds
)

plt.figure(figsize=(8,6))
plt.imshow(cm)
plt.colorbar()

plt.xticks(
    np.arange(len(le.classes_)),
    le.classes_,
    rotation=45
)

plt.yticks(
    np.arange(len(le.classes_)),
    le.classes_
)

plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pickle

with open(
    "label_encoder.pkl",
    "wb"
) as f:

    pickle.dump(le, f)

print("Saved.")
# Out:
# Saved.

# %%
import pickle

with open("label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)

print("Label encoder saved.")
# Out:
# Label encoder saved.

# %%
import torch
import torch.nn as nn
import numpy as np
import pickle
from PIL import Image


class WaferCNN(nn.Module):

    def __init__(self, num_classes):

        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,32,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32,64,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64,128,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128*8*8,256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256,9)
        )

    def forward(self,x):
        x=self.features(x)
        x=self.classifier(x)
        return x


# load encoder
with open("label_encoder.pkl","rb") as f:
    le = pickle.load(f)

# load model
model = WaferCNN(len(le.classes_))
model.load_state_dict(
    torch.load(
        "wafer_best_model.pth",
        map_location="cpu"
    )
)

model.eval()


def predict_wafer(image):

    image = image.convert("RGB")

    image = image.resize((64,64))

    image = np.array(image)

    image = (
        torch.tensor(
            image,
            dtype=torch.float32
        )
        .permute(2,0,1)
        .unsqueeze(0)
        /255.0
    )

    with torch.no_grad():

        output = model(image)

        pred = output.argmax(dim=1).item()

    return le.inverse_transform([pred])[0]

# %%
import sys

# !{sys.executable} -m pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.2 MB 5.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.2 MB 5.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/9.2 MB 4.6 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.2 MB 5.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.2 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 6.0/9.2 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.2 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.2 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 5.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/797.5 kB ? eta -:--:--
#    ---------------------------------------- 797.5/797.5 kB 9.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
# ...

# %%
import streamlit as st

print(st.__version__)
# Out:
# 1.58.0

# %%
st.title("Wafer Defect Classification")
# Out:
# 2026-06-20 11:26:52.664 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:26:52.793
# ...
#   command:
#
#     streamlit run C:\Users\amanv\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-20 11:26:52.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:26:52.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import streamlit as st

st.title("Wafer Defect Classification")
st.write("Model Loaded Successfully")
# Out:
# 2026-06-20 11:30:38.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:30:38.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:30:38.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:30:38.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:30:38.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 11:30:38.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
from PIL import Image
from predict import predict_wafer

st.title(
    "Wafer Defect Classification"
)

uploaded_file = st.file_uploader(
    "Upload Wafer Image",
    type=["png","jpg","jpeg"]
)

if uploaded_file:

    image = Image.open(uploaded_file)

    st.image(
        image,
        caption="Uploaded Wafer",
        use_container_width=True
    )

    prediction = predict_wafer(image)

    st.success(
        f"Predicted Defect: {prediction}"
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[60], line 3
#       1 import streamlit as st
#       2 from PIL import Image
# ----> 3 from predict import predict_wafer
#       4
#       5 st.title(
#       6     "Wafer Defect Classification"
#
# ModuleNotFoundError: No module named 'predict'

# %%
import os

print(os.listdir(r"G:\My Drive"))
# Out:
# ['WA-IMG-20200919-de093c0a.jpg', 'WA-IMG-20200919-7e6fc97b.jpg', 'Photo from Aman Raj', 'CLASS-XII.rar', 'CLASS-XI.rar', 'Aman Raj tutorial sheet .pdf', 'Emailing mos differential pair tutorial 3 soln Aman Raj.pdf', 'Document from Aman Raj.pdf', 'aman class X marksheet.pdf', 'class X marksheet amaan.pdf', 'Aman Raj grade card 1-4.pdf', 'archive.zip', 'archive (1).zip', 'Colab Notebooks', 'wm-811k.zip', 'wafer_data', 'wafer_best_model.pth', 'wafer_checkpoint.pth', 'wafer_project', 'desktop.ini']

# %%
import os

print(os.listdir(r"G:\My Drive\wafer_project"))
# Out:
# []

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\amanv

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.android', '.aws', '.azure', '.cache', '.codex', '.conda', '.continuum', '.docker', '.env', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.ms-ad', '.python_history', '.streamlit', '.vscode', 'aiim001_task_1.zip', 'aiim001_task_2.zip', 'aiim001_task_3.zip', 'aiim001_task_4.zip', 'aiim001_task_5.zip', 'aiim001_task_6.zip', 'aman', 'AppData', 'Application Data', 'arousal.txt', 'avcaffe', 'best_fer_model.pth.zip', 'best_model.pth', 'bin1.png', 'bin2.png', 'c++ cde', 'clip_df.pkl', 'Contacts', 'Cookies', 'datastruAssign', 'Documents', 'dominance.txt', 'Downloads', 'effort.txt', 'Favorites', 'frustration.txt', 'gitworkshop', 'gravity.cpp', 'gravity2.cpp', 'gravity3.cpp', 'img1.jpg', 'img2.jpg', 'img3.jpg', 'img4.jpg', 'img5.jpg', 'img6.jpg', 'JupyterProjects', 'label_encoder.pkl', 'Local Settings', 'mental_demand.txt', 'Music', 'My Documents', 'myenv', 'NetHood', 'no_audio_files.txt', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.D
# ...

# %%
import shutil

shutil.copy(
    "wafer_best_model.pth",
    r"G:\My Drive\wafer_project\wafer_best_model.pth"
)

shutil.copy(
    "label_encoder.pkl",
    r"G:\My Drive\wafer_project\label_encoder.pkl"
)

print("Files copied successfully!")
# Out:
# Files copied successfully!

# %%
import os

print(os.listdir(r"G:\My Drive\wafer_project"))
# Out:
# ['wafer_best_model.pth', 'label_encoder.pkl']

# %%
import os

print(os.listdir(r"G:\My Drive\wafer_project"))
# Out:
# ['wafer_best_model.pth', 'label_encoder.pkl', 'app.py']

# %%
print(model)
# Out:
# WaferCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=8192, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=256, out_features=9, bias=True)
#   )
# )

# %%
import torch
import torch.nn as nn
import numpy as np
import pickle
from PIL import Image


class WaferCNN(nn.Module):

    def __init__(self, num_classes):

        super().__init__()

        self.features = nn.Sequential(

            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(

            nn.Flatten(),

            nn.Linear(
                128 * 8 * 8,
                256
            ),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(
                256,
                num_classes
            )
        )

    def forward(self, x):

        x = self.features(x)

        x = self.classifier(x)

        return x


with open("label_encoder.pkl", "rb") as f:
    le = pickle.load(f)

model = WaferCNN(
    len(le.classes_)
)

model.load_state_dict(
    torch.load(
        "wafer_best_model.pth",
        map_location="cpu"
    )
)

model.eval()


def predict_wafer(image):

    image = image.convert("RGB")

    image = image.resize((64, 64))

    image = np.array(image)

    image = (
        torch.tensor(
            image,
            dtype=torch.float32
        )
        .permute(2, 0, 1)
        .unsqueeze(0)
        / 255.0
    )

    with torch.no_grad():

        output = model(image)

        pred = output.argmax(
            dim=1
        ).item()

    return le.inverse_transform(
        [pred]
    )[0]

# %%
import os

print(os.listdir(r"G:\My Drive\wafer_project"))
# Out:
# ['wafer_best_model.pth', 'label_encoder.pkl', 'app.py', 'predict.py']

# %%
with open(r"G:\My Drive\wafer_project\app.py", "r") as f:
    print(f.read()[:300])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[71], line 2
#       1 with open(r"G:\My Drive\wafer_project\app.py", "r") as f:
# ----> 2     print(f.read()[:300])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 193: character maps to <undefined>

# %%
app_code = """
import streamlit as st
from PIL import Image
from predict import predict_wafer

st.set_page_config(
    page_title="Wafer Defect Classification",
    layout="centered"
)

st.title("Wafer Defect Classification")

st.write(
    "Upload a wafer map image and the model will predict the defect type."
)

uploaded_file = st.file_uploader(
    "Choose a wafer image",
    type=["png", "jpg", "jpeg"]
)

if uploaded_file is not None:

    image = Image.open(uploaded_file)

    st.image(
        image,
        caption="Uploaded Wafer Image",
        use_container_width=True
    )

    with st.spinner("Predicting..."):
        prediction = predict_wafer(image)

    st.success(
        f"Predicted Defect Type: {prediction}"
    )
"""

with open(
    r"G:\My Drive\wafer_project\app.py",
    "w",
    encoding="utf-8"
) as f:
    f.write(app_code)

print("app.py updated successfully")
# Out:
# app.py updated successfully

# %%
with open(
    r"G:\My Drive\wafer_project\app.py",
    "r",
    encoding="utf-8"
) as f:
    print(f.read()[:300])
# Out:
# import streamlit as st
# from PIL import Image
# from predict import predict_wafer
#
# st.set_page_config(
#     page_title="Wafer Defect Classification",
#     layout="centered"
# )
#
# st.title("Wafer Defect Classification")
#
# st.write(
#     "Upload a wafer map image and the model will predict the defect type."
# )

# %%
import os

size_mb = os.path.getsize(
    r"G:\My Drive\wafer_project\wafer_best_model.pth"
)/(1024*1024)

print(size_mb)
# Out:
# 8.369893074035645

# %%
import os

print(os.listdir(r"G:\My Drive\wafer_project"))
# Out:
# ['wafer_best_model.pth', 'label_encoder.pkl', 'app.py', 'predict.py', '__pycache__']
